# %%
# Install the necessary libraries
# !pip install -q pandas scikit-learn

import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np

# Load the dataset from Google Drive
from google.colab import files
uploaded = files.upload()

file_name = list(uploaded.keys())[0]
data = pd.read_csv(file_name)

# Display the first few rows of the dataset to understand its structure
print("First few rows of the dataset:")
print(data.head())

# Extracting the independent (x) and dependent (y) variables
X = data[['x']].values
y = data['y'].values

# Initializing and fitting the linear regression model
model = LinearRegression()
model.fit(X, y)

# Predicting the value of y at x = 50
x_new = np.array([[50]])
y_pred = model.predict(x_new)

# Print the predicted value
print(f"The predicted value of y at x = 50 is {y_pred[0]}")
# Out:
#      <input type="file" id="files-560ea9a5-7947-4366-a880-1c45592e99f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-560ea9a5-7947-4366-a880-1c45592e99f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# The negative prediction indicates that the linear trend inferred from the data suggests a decreasing relationship, and at
# 𝑥
# =
# 50
# x=50, the model estimates
# 𝑦
# y to be slightly negative.
#
# ---
# We can double-check by visualizing the data and the fitted line to ensure that the linear model appropriately captures the trend in the data.

# %%
import matplotlib.pyplot as plt

# Plot the data points
plt.scatter(X, y, color='blue', label='Data Points')

# Plot the regression line
plt.plot(X, model.predict(X), color='red', label='Fitted Line')

# Mark the prediction at x = 50
plt.scatter([50], [y_pred[0]], color='green', marker='x', s=100, label=f'Prediction at x=50: {y_pred[0]:.2f}')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.title('Linear Regression Fit')
plt.show()
